# %%
import pandas as pd
import numpy as np
import scipy.stats as ss

data = pd.read_csv('data.txt')
nump = data.to_numpy()
state,gender,year,name,freq = 0,1,2,3,4

# %%
def female_count(name, data = nump):
    count = 0
    for i in col:
        if (i[3] == name):
            if (i[gender] == 'F'):
                count += i[freq]
    return count


def male_count(name, data = nump):
    count = 0
    for i in col:
        if (i[3] == name):
            if (i[gender] == 'M'):
                count += i[freq]
    return count


def all_count(name, data = nump):
    count = 0
    for i in col:
        if (i[3] == name):
            count += i[freq]
    return count
